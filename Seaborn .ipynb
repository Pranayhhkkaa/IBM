# %%
import seaborn as sns

# %%
import matplotlib as polt

# %%
df2=[90,75,60,45,30,15,45,96,56]
bins=[]
for i in range(0,101,10):
    bins.append(i)
    
sns.displot(df2,bins=bins,kde=True)

# %%
# Histogram

# %%
from matplotlib import pyplot as plt

# %%
df=sns.load_dataset('iris')

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.distplot(df['petal_length'],kde=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19096\1038348431.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'],kde=False)
# <Axes: xlabel='petal_length'>

# %%
# KDE

# %%
sns.distplot(df['petal_length'],hist=False)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19096\187855619.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'],hist=False)
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
# Line graph

# %%
from matplotlib import pyplot as plt

# %%
x=[34,52,62,54,22,36]
y=[55,25,63,42,51,42]
plt.plot(x,y,"*",markersize=12)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('sdfdf')
plt.show()

# %%
plt.plot(x,y,"*",markersize=12)

# %%
x=[2,8,4,7]
y=[5,3,9,6]

# %%
plt.plot(x,y)

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\Latest Covid-19 India Status.csv")

# %%
df.head()
# Out:
#              State/UTs  Total Cases  Active  Discharged  Deaths  Active Ratio  \
# 0  Andaman and Nicobar        10766       0       10637     129           0.0
# 1       Andhra Pradesh      2340676       0     2325943   14733           0.0
# 2    Arunachal Pradesh        67049       0       66753     296           0.0
# 3                Assam       746159       5      738119    8035           0.0
# 4                Bihar       855267       1      842952   12314           0.0
#
#    Discharge Ratio  Death Ratio  Population
# 0            98.80         1.20   100896618
# 1            99.37         0.63   128500364
# 2            99.56         0.44      658019
# 3            98.92         1.08      290492
# 4            98.56         1.44    40100376

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
plt.plot(df['Deaths'],df['Total Cases'])

# %%
# Scatter plot

# %%
x
# Out:
# [2, 8, 4, 7]

# %%
y
# Out:
# [5, 3, 9, 6]

# %%
plt.scatter(x,y)

# %%
x=[3,2,1]

# %%
y=[3,2,1]

# %%
plt.scatter(x,y)

# %%
plt.figure(figsize=(100,50))
plt.scatter(df['Deaths'],df['Total Cases'])

# %%
plt.scatter(df['Deaths'],df['Total Cases'])

# %%
# Bar graph

# %%
data=['Python','Java','Testing','AWS']

# %%
enroll=[75.6,25,200,16]

# %%
plt.bar(data,enroll)
# Out:
# <BarContainer object of 4 artists>

# %%
df
# Out:
#                                    State/UTs  Total Cases  Active  Discharged  \
# 0                        Andaman and Nicobar        10766       0       10637
# 1                             Andhra Pradesh      2340676       0     2325943
# 2                          Arunachal Pradesh        67049       0       66753
# 3                                      Assam       746159       5      738119
# 4                                      Bihar       855267       1      842952
# 5                                 Chandigarh       100693       0       99508
# 6                               Chhattisgarh      1187695       0     1173505
# 7   Dadra and Nagar Haveli and Daman and Diu        11592       0       11588
# 8                                      Delhi      2040910      14     2014230
# 9                                        Goa       263346       3      259329
# 10                                   Gujarat      1291383       5     1280299
# ...

# %%
plt.hist(df['Deaths'])
# Out:
# (array([28.,  4.,  2.,  0.,  1.,  0.,  0.,  0.,  0.,  1.]),
#  array([4.000000e+00, 1.485940e+04, 2.971480e+04, 4.457020e+04,
#         5.942560e+04, 7.428100e+04, 8.913640e+04, 1.039918e+05,
#         1.188472e+05, 1.337026e+05, 1.485580e+05]),
#  <BarContainer object of 10 artists>)
