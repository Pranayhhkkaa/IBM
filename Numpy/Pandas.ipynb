# %%
import pandas as pd

# %%
df1=pd.read_csv(r"C:\Users\User\Downloads\Bengaluru_House_Data.csv")

# %%
df1.head(3)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00

# %%
df1['avg_price']=df1.apply(lambda x:x['area_type'] if x ['price']>50 else None,axis=1)
print(df1)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price  \
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df['new_col']=df.apply(lambda x:x [col_name] if x ['cil_name'] >50 else None,axis=1)
print(df)

# %%
df.shape
# Out:
# (13320, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13320 entries, 0 to 13319
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     13320 non-null  object
#  1   availability  13320 non-null  object
#  2   location      13319 non-null  object
#  3   size          13304 non-null  object
#  4   society       7818 non-null   object
#  5   total_sqft    13320 non-null  object
#  6   bath          13247 non-null  float64
#  7   balcony       12711 non-null  float64
#  8   price         13320 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 936.7+ KB

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.sample(5)
# Out:
#                   area_type   availability           location       size  \
# 5785   Super built-up  Area  Ready To Move        Uttarahalli      3 BHK
# 5983   Super built-up  Area  Ready To Move  Bannerghatta Road      2 BHK
# 12137  Super built-up  Area  Ready To Move       Haralur Road      2 BHK
# 3030             Plot  Area  Ready To Move     Ambedkar Nagar  5 Bedroom
# 2900             Plot  Area         18-Apr         Nagarbhavi  3 Bedroom
#
#        society   total_sqft  bath  balcony   price
# 5785       NaN         1490   2.0      2.0   59.60
# 5983   SNity S  1255 - 1350   2.0      0.0   67.73
# 12137  RInceeg         1243   2.0      2.0   46.00
# 3030   Thessrm         5530   5.0      3.0  627.00
# 2900       NaN          600   3.0      1.0   83.00

# %%
df.describe()
# Out:
#                bath       balcony         price
# count  13247.000000  12711.000000  13320.000000
# mean       2.692610      1.584376    112.565627
# std        1.341458      0.817263    148.971674
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     72.000000
# 75%        3.000000      2.000000    120.000000
# max       40.000000      3.000000   3600.000000

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                  13320          13320       13319  13304     7818
# unique                     4             81        1305     31     2688
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    8790          10581         540   5199       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft          bath       balcony         price
# ...

# %%
df[['area_type','location','total_sqft']]
# Out:
#                   area_type                  location total_sqft
# 0      Super built-up  Area  Electronic City Phase II       1056
# 1                Plot  Area          Chikka Tirupathi       2600
# 2            Built-up  Area               Uttarahalli       1440
# 3      Super built-up  Area        Lingadheeranahalli       1521
# 4      Super built-up  Area                  Kothanur       1200
# ...                     ...                       ...        ...
# 13315        Built-up  Area                Whitefield       3453
# 13316  Super built-up  Area             Richards Town       3600
# 13317        Built-up  Area     Raja Rajeshwari Nagar       1141
# 13318  Super built-up  Area           Padmanabhanagar       4689
# 13319  Super built-up  Area              Doddathoguru        550
#
# [13320 rows x 3 columns]

# %%
df.head(3)
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00

# %%
rename=df.rename({'location':'new_location'},axis=1)

# %%
rename
# Out:
#                   area_type   availability              new_location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.rename({'Uttarahalli':'55BHK'},axis=1)
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.rename({'bath':'new_bath'},axis=1,inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  new_bath  balcony   price
# 0          2 BHK  Coomee        1056       2.0      1.0   39.07
# ...

# %%
rename.set_index('size')
# Out:
#                       area_type   availability              new_location  \
# size
# 2 BHK      Super built-up  Area         19-Dec  Electronic City Phase II
# 4 Bedroom            Plot  Area  Ready To Move          Chikka Tirupathi
# 3 BHK            Built-up  Area  Ready To Move               Uttarahalli
# 3 BHK      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 2 BHK      Super built-up  Area  Ready To Move                  Kothanur
# ...                         ...            ...                       ...
# 5 Bedroom        Built-up  Area  Ready To Move                Whitefield
# 4 BHK      Super built-up  Area  Ready To Move             Richards Town
# 2 BHK            Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 4 BHK      Super built-up  Area         18-Jun           Padmanabhanagar
# 1 BHK      Super built-up  Area  Ready To Move              Doddathoguru
#
#            society total_sqft  bath  balcony   price
# size
# ...

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  new_bath  balcony   price
# 0          2 BHK  Coomee        1056       2.0      1.0   39.07
# ...

# %%
df.loc[:10,['availability','total_sqft']]
# Out:
#      availability total_sqft
# 0          19-Dec       1056
# 1   Ready To Move       2600
# 2   Ready To Move       1440
# 3   Ready To Move       1521
# 4   Ready To Move       1200
# 5   Ready To Move       1170
# 6          18-May       2732
# 7   Ready To Move       3300
# 8   Ready To Move       1310
# 9   Ready To Move       1020
# 10         18-Feb       1800

# %%
df.iloc[:10,2:5]
# Out:
#                    location       size  society
# 0  Electronic City Phase II      2 BHK  Coomee
# 1          Chikka Tirupathi  4 Bedroom  Theanmp
# 2               Uttarahalli      3 BHK      NaN
# 3        Lingadheeranahalli      3 BHK  Soiewre
# 4                  Kothanur      2 BHK      NaN
# 5                Whitefield      2 BHK  DuenaTa
# 6          Old Airport Road      4 BHK  Jaades
# 7              Rajaji Nagar      4 BHK  Brway G
# 8              Marathahalli      3 BHK      NaN
# 9              Gandhi Bazar  6 Bedroom      NaN

# %%
df["Age"]=25

# %%
df.loc[2,'Age']=35

# %%
df.drop('age',axis=1,inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  new_bath  balcony   price  Age
# 0          2 BHK  Coomee        1056       2.0      1.0   39.07   25
# ...

# %%
df.drop(columns=['Age','size'],axis=1,inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  society  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  Theanmp
# 2            Built-up  Area  Ready To Move               Uttarahalli      NaN
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  Soiewre
# 4      Super built-up  Area  Ready To Move                  Kothanur      NaN
# ...                     ...            ...                       ...      ...
# 13315        Built-up  Area  Ready To Move                Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move             Richards Town      NaN
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  SollyCl
# 13319  Super built-up  Area  Ready To Move              Doddathoguru      NaN
#
# ...

# %%
df.drop(13319,inplace=True)

# %%
df
# Out:
#                   area_type   availability                  location  society  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II  Coomee
# 1                Plot  Area  Ready To Move          Chikka Tirupathi  Theanmp
# 2            Built-up  Area  Ready To Move               Uttarahalli      NaN
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli  Soiewre
# 4      Super built-up  Area  Ready To Move                  Kothanur      NaN
# ...                     ...            ...                       ...      ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move                Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move             Richards Town      NaN
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar  SollyCl
#
# ...

# %%
df.drop([i for i in range(0,11)],inplace=True)

# %%
df
# Out:
#                   area_type   availability               location  society  \
# 11               Plot  Area  Ready To Move             Whitefield  Prrry M
# 12     Super built-up  Area  Ready To Move     7th Phase JP Nagar  Shncyes
# 13           Built-up  Area  Ready To Move              Gottigere      NaN
# 14               Plot  Area  Ready To Move               Sarjapur  Skityer
# 15     Super built-up  Area  Ready To Move            Mysore Road  PrntaEn
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df.drop(list(range(11,100)),inplace=True)

# %%
df
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
len(df['location'])
# Out:
# 13219

# %%
df['area_type'].unique()
# Out:
# array(['Super built-up  Area', 'Built-up  Area', 'Plot  Area',
#        'Carpet  Area'], dtype=object)

# %%
df['area_type'].value_counts()
# Out:
# Super built-up  Area    8725
# Built-up  Area          2398
# Plot  Area              2009
# Carpet  Area              87
# Name: area_type, dtype: int64

# %%
df.sort_values('area_type')
# Out:
#                   area_type   availability              location  society  \
# 5855         Built-up  Area  Ready To Move          Haralur Road  NDionas
# 2254         Built-up  Area  Ready To Move           Bommasandra  Vaodspe
# 11912        Built-up  Area  Ready To Move               Kengeri      NaN
# 2257         Built-up  Area  Ready To Move          Upkar Layout      NaN
# 5436         Built-up  Area  Ready To Move  Nagappa Reddy Layout      NaN
# ...                     ...            ...                   ...      ...
# 5420   Super built-up  Area  Ready To Move     Byagadadhenahalli  VBavaai
# 5421   Super built-up  Area         18-Jun           Bommasandra  SSestth
# 5424   Super built-up  Area  Ready To Move            HSR Layout  SrisePo
# 5401   Super built-up  Area  Ready To Move            Whitefield  Gotis A
# 13318  Super built-up  Area         18-Jun       Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony   price
# ...

# %%
df
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df.replace(['Yeshwanthpur'],['Python is a nice labnguafns'])
# Out:
#                   area_type   availability                     location  \
# 100    Super built-up  Area  Ready To Move  Python is a nice labnguafns
# 101          Built-up  Area  Ready To Move                   Chandapura
# 102              Plot  Area  Ready To Move                     Kothanur
# 103    Super built-up  Area  Ready To Move            Green View Layout
# 104    Super built-up  Area  Ready To Move         Shantiniketan Layout
# ...                     ...            ...                          ...
# 13314  Super built-up  Area  Ready To Move            Green Glen Layout
# 13315        Built-up  Area  Ready To Move                   Whitefield
# 13316  Super built-up  Area  Ready To Move                Richards Town
# 13317        Built-up  Area  Ready To Move        Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun              Padmanabhanagar
#
#        society total_sqft  new_bath  balcony  price
# ...

# %%
df
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df[df['location']=='Green View Layout'][['area_type','price','location']]
# Out:
#                   area_type  price           location
# 103    Super built-up  Area   43.0  Green View Layout
# 5956   Super built-up  Area   36.0  Green View Layout
# 6810         Built-up  Area   40.0  Green View Layout
# 9301   Super built-up  Area   48.0  Green View Layout
# 10447        Built-up  Area   42.0  Green View Layout
# 12511        Built-up  Area   45.0  Green View Layout
# 13162        Built-up  Area   41.0  Green View Layout

# %%
df[(df['location']=='Green View Layout')|(df['location']=='Chandapura')].head(6)
# Out:
#                 area_type   availability           location  society  \
# 101        Built-up  Area  Ready To Move         Chandapura  KHityry
# 103  Super built-up  Area  Ready To Move  Green View Layout  Makeser
# 240  Super built-up  Area         18-Aug         Chandapura  SunceEs
# 242  Super built-up  Area         18-Sep         Chandapura  SunceEs
# 250  Super built-up  Area  Ready To Move         Chandapura  KHityry
# 289  Super built-up  Area         18-Jul         Chandapura  SunceEs
#
#     total_sqft  new_bath  balcony  price
# 101        650       1.0      1.0  17.00
# 103       1007       2.0      2.0  43.00
# 240        645       1.0      1.0  16.45
# 242        645       1.0      1.0  16.45
# 250        800       1.0      1.0  20.00
# 289       1015       2.0      2.0  25.88

# %%
df['price'].median()
# Out:
# 72.0

# %%
df.drop_duplicates()
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df.dropna()
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13313  Super built-up  Area  Ready To Move            Uttarahalli  Aklia R
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
12691-7444
# Out:
# 5247

# %%
df.dropna(how='all')
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df.shape
# Out:
# (13219, 8)

# %%
df.fillna(0)
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town        0
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
obj=df.groupby('location')

# %%
obj

# %%
obj.get_group('Yeshwanthpur')
# Out:
#                   area_type   availability      location  society total_sqft  \
# 100    Super built-up  Area  Ready To Move  Yeshwanthpur  IBityin       2502
# 392    Super built-up  Area         18-Aug  Yeshwanthpur  Aroomba       1693
# 763    Super built-up  Area  Ready To Move  Yeshwanthpur  IBityin        667
# 825    Super built-up  Area         20-Dec  Yeshwanthpur  Detat H       1950
# 867          Built-up  Area  Ready To Move  Yeshwanthpur  IBityin       1170
# ...                     ...            ...           ...      ...        ...
# 12627  Super built-up  Area  Ready To Move  Yeshwanthpur  IBityin       1676
# 12850  Super built-up  Area  Ready To Move  Yeshwanthpur  IBityin       2503
# 13017  Super built-up  Area  Ready To Move  Yeshwanthpur  Goandn        1855
# 13124  Super built-up  Area  Ready To Move  Yeshwanthpur      NaN       1876
# 13309  Super built-up  Area  Ready To Move  Yeshwanthpur  IBityin       1675
#
#        new_bath  balcony   price
# ...

# %%
obj.min()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19484\3119354513.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   obj.min()
#                                  area_type   availability total_sqft  \
# location
#  Anekal                     Built-up  Area  Ready To Move        351
#  Banaswadi            Super built-up  Area  Ready To Move        527
#  Basavangudi          Super built-up  Area  Ready To Move        670
#  Bhoganhalli          Super built-up  Area         19-Dec        296
#  Devarabeesana Halli        Built-up  Area  Ready To Move       1100
# ...                                    ...            ...        ...
# t.c palya                       Plot  Area  Ready To Move       1350
# tc.palya                        Plot  Area         18-Apr       1000
# ...

# %%
obj.describe()
# Out:
#                      new_bath                                                \
#                         count      mean       std  min   25%  50%  75%  max
# location
#  Anekal                   1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
#  Banaswadi                1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
#  Basavangudi              1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
#  Bhoganhalli              1.0  1.000000       NaN  1.0  1.00  1.0  1.0  1.0
#  Devarabeesana Halli      6.0  2.666667  0.516398  2.0  2.25  3.0  3.0  3.0
# ...                       ...       ...       ...  ...   ...  ...  ...  ...
# t.c palya                 1.0  6.000000       NaN  6.0  6.00  6.0  6.0  6.0
# tc.palya                  4.0  2.000000  0.000000  2.0  2.00  2.0  2.0  2.0
# vinayakanagar             1.0  5.000000       NaN  5.0  5.00  5.0  5.0  5.0
# white field,kadugodi      1.0  6.000000       NaN  6.0  6.00  6.0  6.0  6.0
# ...

# %%
df['location']=df['location'].astype('int32')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 df['location']=df['location'].astype('int32')
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df
# Out:
#                   area_type   availability               location  society  \
# 100    Super built-up  Area  Ready To Move           Yeshwanthpur  IBityin
# 101          Built-up  Area  Ready To Move             Chandapura  KHityry
# 102              Plot  Area  Ready To Move               Kothanur  BDensar
# 103    Super built-up  Area  Ready To Move      Green View Layout  Makeser
# 104    Super built-up  Area  Ready To Move   Shantiniketan Layout  Maest N
# ...                     ...            ...                    ...      ...
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout  SoosePr
# 13315        Built-up  Area  Ready To Move             Whitefield  ArsiaEx
# 13316  Super built-up  Area  Ready To Move          Richards Town      NaN
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar  Mahla T
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar  SollyCl
#
#       total_sqft  new_bath  balcony  price
# ...

# %%
df['balcony']=df['balcony'].astype('int32')

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# society          object
# total_sqft       object
# new_bath        float64
# balcony           int32
# price           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
emp_details={'ID':[1,2,3],'Name':["Pranay",'Rashmi','Pratik'],'Location':['Pune','Mumbai','Nashik']}

# %%
df1=pd.DataFrame(emp_details)

# %%
df1
# Out:
#    ID    Name Location
# 0   1  Pranay     Pune
# 1   2  Rashmi   Mumbai
# 2   3  Pratik   Nashik

# %%
df1.loc[2,'Location']='Channie'

# %%
df1
# Out:
#    ID    Name Location
# 0   1  Pranay     Pune
# 1   2  Rashmi   Mumbai
# 2   3  Pratik  Channie

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.size
# Out:
# 119880

# %%
df.shape
# Out:
# (13320, 9)

# %%
13320*9
# Out:
# 119880

# %%
df.describe().T
# Out:
#            count        mean         std  min   25%   50%    75%     max
# bath     13247.0    2.692610    1.341458  1.0   2.0   2.0    3.0    40.0
# balcony  12711.0    1.584376    0.817263  0.0   1.0   2.0    2.0     3.0
# price    13320.0  112.565627  148.971674  8.0  50.0  72.0  120.0  3600.0

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df.sample(n=10)
# Out:
#                   area_type   availability              location       size  \
# 135          Built-up  Area  Ready To Move        Kanakpura Road      2 BHK
# 1952   Super built-up  Area  Ready To Move          Ashwathnagar      3 BHK
# 9604   Super built-up  Area  Ready To Move          Banashankari      2 BHK
# 1326   Super built-up  Area  Ready To Move          Bommanahalli      2 BHK
# 5764   Super built-up  Area  Ready To Move          Banashankari      2 BHK
# 1157   Super built-up  Area  Ready To Move          Marathahalli      3 BHK
# 13000            Plot  Area  Ready To Move  Agrahara Dasarahalli  3 Bedroom
# 6320   Super built-up  Area  Ready To Move          Yeshwanthpur      3 BHK
# 11871  Super built-up  Area  Ready To Move             Yelahanka      3 BHK
# 4456   Super built-up  Area  Ready To Move           Thanisandra      3 BHK
#
#        society total_sqft  bath  balcony   price
# 135    Wiowsri        950   2.0      1.0   57.00
# ...

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %%
df1
# Out:
#    ID    Name Location
# 0   1  Pranay     Pune
# 1   2  Rashmi   Mumbai
# 2   3  Pratik  Channie

# %%
df.loc['df1'].iloc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[136], line 1
# ----> 1 df.loc['df1'].iloc[1:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\data.csv")

# %%
df.head(3)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0        2.0         1930     11947
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA

# %%
df.shape
# Out:
# (4600, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   float64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
#        'floors', 'waterfront', 'view', 'condition', 'sqft_above',
#        'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city',
#        'statezip', 'country'],
#       dtype='object')

# %%
df.head(3)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0        1.5         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0        2.5         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0        2.0         1930     11947
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
#
#    yr_renovated                    street       city  statezip country
# 0          2005      18810 Densmore Ave N  Shoreline  WA 98133     USA
# 1             0           709 W Blaine St    Seattle  WA 98119     USA
# 2             0  26206-26214 143rd Ave SE       Kent  WA 98042     USA

# %%
df.tail(5)
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 4595  2014-07-09 00:00:00  308166.666667       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  534333.333333       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  416904.166667       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  203400.000000       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  220600.000000       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# ...

# %%
df.sample(5)
# Out:
#                      date     price  bedrooms  bathrooms  sqft_living  \
# 1681  2014-06-02 00:00:00  661000.0       4.0       2.25         1990
# 120   2014-05-05 00:00:00  379950.0       4.0       1.75         1970
# 1424  2014-05-28 00:00:00  799000.0       4.0       3.00         2580
# 2194  2014-06-10 00:00:00  175000.0       6.0       1.50         1930
# 2003  2014-06-05 00:00:00  560000.0       4.0       2.50         2260
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 1681      4600     1.5           0     2          4        1420
# 120       9389     1.0           0     0          5        1140
# 1424    209523     2.0           0     0          3        2580
# 2194      8400     1.0           0     0          3        1030
# 2003      3713     2.0           0     0          3        2260
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 1681            570      1932          1958   4426 38th Ave SW    Seattle
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.describe(include='all')
# Out:
#                        date         price     bedrooms    bathrooms  \
# count                  4600  4.600000e+03  4600.000000  4600.000000
# unique                   70           NaN          NaN          NaN
# top     2014-06-23 00:00:00           NaN          NaN          NaN
# freq                    142           NaN          NaN          NaN
# mean                    NaN  5.519630e+05     3.400870     2.160815
# std                     NaN  5.638347e+05     0.908848     0.783781
# min                     NaN  0.000000e+00     0.000000     0.000000
# 25%                     NaN  3.228750e+05     3.000000     1.750000
# 50%                     NaN  4.609435e+05     3.000000     2.250000
# 75%                     NaN  6.549625e+05     4.000000     2.500000
# max                     NaN  2.659000e+07     9.000000     8.000000
#
#          sqft_living      sqft_lot       floors   waterfront         view  \
# count    4600.000000  4.600000e+03  4600.000000  4600.000000  4600.000000
# ...

# %%
df.describe().T
# Out:
#                 count           mean            std     min        25%  \
# price          4600.0  551962.988473  563834.702547     0.0  322875.00
# bedrooms       4600.0       3.400870       0.908848     0.0       3.00
# bathrooms      4600.0       2.160815       0.783781     0.0       1.75
# sqft_living    4600.0    2139.346957     963.206916   370.0    1460.00
# sqft_lot       4600.0   14852.516087   35884.436145   638.0    5000.75
# floors         4600.0       1.512065       0.538288     1.0       1.00
# waterfront     4600.0       0.007174       0.084404     0.0       0.00
# view           4600.0       0.240652       0.778405     0.0       0.00
# condition      4600.0       3.451739       0.677230     1.0       3.00
# sqft_above     4600.0    1827.265435     862.168977   370.0    1190.00
# sqft_basement  4600.0     312.081522     464.137228     0.0       0.00
# yr_built       4600.0    1970.786304      29.731848  1900.0    1951.00
# ...

# %%
df.price
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
df['price']
# Out:
# 0       3.130000e+05
# 1       2.384000e+06
# 2       3.420000e+05
# 3       4.200000e+05
# 4       5.500000e+05
#             ...
# 4595    3.081667e+05
# 4596    5.343333e+05
# 4597    4.169042e+05
# 4598    2.034000e+05
# 4599    2.206000e+05
# Name: price, Length: 4600, dtype: float64

# %%
df[['price','floors']]
# Out:
#              price  floors
# 0     3.130000e+05     1.5
# 1     2.384000e+06     2.0
# 2     3.420000e+05     1.0
# 3     4.200000e+05     1.0
# 4     5.500000e+05     1.0
# ...            ...     ...
# 4595  3.081667e+05     1.0
# 4596  5.343333e+05     2.0
# 4597  4.169042e+05     2.0
# 4598  2.034000e+05     1.0
# 4599  2.206000e+05     2.0
#
# [4600 rows x 2 columns]

# %%
p=df[[col for col in df.columns if col not in ['price','floors']]]

# %%
p
# Out:
#                      date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02 00:00:00       3.0       1.50         1340      7912
# 1     2014-05-02 00:00:00       5.0       2.50         3650      9050
# 2     2014-05-02 00:00:00       3.0       2.00         1930     11947
# 3     2014-05-02 00:00:00       3.0       2.25         2000      8030
# 4     2014-05-02 00:00:00       4.0       2.50         1940     10500
# ...                   ...       ...        ...          ...       ...
# 4595  2014-07-09 00:00:00       3.0       1.75         1510      6360
# 4596  2014-07-09 00:00:00       3.0       2.50         1460      7573
# 4597  2014-07-09 00:00:00       3.0       2.50         3010      7014
# 4598  2014-07-10 00:00:00       4.0       2.00         2090      6630
# 4599  2014-07-10 00:00:00       3.0       2.50         1490      8102
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df.rename({'price':'New_prices'},axis=1)
# Out:
#                      date    New_prices  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
new=df.describe().T

# %%
new.rename({'price':'New_price'},axis=0)
# Out:
#                 count           mean            std     min        25%  \
# New_price      4600.0  551962.988473  563834.702547     0.0  322875.00
# bedrooms       4600.0       3.400870       0.908848     0.0       3.00
# bathrooms      4600.0       2.160815       0.783781     0.0       1.75
# sqft_living    4600.0    2139.346957     963.206916   370.0    1460.00
# sqft_lot       4600.0   14852.516087   35884.436145   638.0    5000.75
# floors         4600.0       1.512065       0.538288     1.0       1.00
# waterfront     4600.0       0.007174       0.084404     0.0       0.00
# view           4600.0       0.240652       0.778405     0.0       0.00
# condition      4600.0       3.451739       0.677230     1.0       3.00
# sqft_above     4600.0    1827.265435     862.168977   370.0    1190.00
# sqft_basement  4600.0     312.081522     464.137228     0.0       0.00
# yr_built       4600.0    1970.786304      29.731848  1900.0    1951.00
# ...

# %%
df.rename({'bedrooms':'Bedroom'},axis=1,inplace=True)

# %%
df
# Out:
#                      date         price  Bedroom  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05      3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06      5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05      3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05      3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05      4.0       2.50         1940
# ...                   ...           ...      ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05      3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05      3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05      3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05      4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05      3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.set_index('sqft_lot',inplace=True)

# %%
df
# Out:
#                          date         price  Bedroom  bathrooms  sqft_living  \
# sqft_lot
# 7912      2014-05-02 00:00:00  3.130000e+05      3.0       1.50         1340
# 9050      2014-05-02 00:00:00  2.384000e+06      5.0       2.50         3650
# 11947     2014-05-02 00:00:00  3.420000e+05      3.0       2.00         1930
# 8030      2014-05-02 00:00:00  4.200000e+05      3.0       2.25         2000
# 10500     2014-05-02 00:00:00  5.500000e+05      4.0       2.50         1940
# ...                       ...           ...      ...        ...          ...
# 6360      2014-07-09 00:00:00  3.081667e+05      3.0       1.75         1510
# 7573      2014-07-09 00:00:00  5.343333e+05      3.0       2.50         1460
# 7014      2014-07-09 00:00:00  4.169042e+05      3.0       2.50         3010
# 6630      2014-07-10 00:00:00  2.034000e+05      4.0       2.00         2090
# 8102      2014-07-10 00:00:00  2.206000e+05      3.0       2.50         1490
#
# ...

# %%
df.loc[:,['price']]
# Out:
#                  price
# sqft_lot
# 7912      3.130000e+05
# 9050      2.384000e+06
# 11947     3.420000e+05
# 8030      4.200000e+05
# 10500     5.500000e+05
# ...                ...
# 6360      3.081667e+05
# 7573      5.343333e+05
# 7014      4.169042e+05
# 6630      2.034000e+05
# 8102      2.206000e+05
#
# [4600 rows x 1 columns]

# %%
df.iloc[:,2:4]
# Out:
#           Bedroom  bathrooms
# sqft_lot
# 7912          3.0       1.50
# 9050          5.0       2.50
# 11947         3.0       2.00
# 8030          3.0       2.25
# 10500         4.0       2.50
# ...           ...        ...
# 6360          3.0       1.75
# 7573          3.0       2.50
# 7014          3.0       2.50
# 6630          4.0       2.00
# 8102          3.0       2.50
#
# [4600 rows x 2 columns]

# %%
df['Python']=500

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.loc[4599,'yr_built']=2020

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.drop(columns=['waterfront','sqft_basement'],axis=1,inplace=True)

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  view  condition  sqft_above  yr_built  yr_renovated  \
# ...

# %%
len(df['bedrooms'])
# Out:
# 4600

# %%
df['bedrooms'].unique()
# Out:
# array([3., 5., 4., 2., 6., 7., 9., 1., 8., 0.])

# %%
df['bedrooms'].value_counts()
# Out:
# 3.0    2032
# 4.0    1531
# 2.0     566
# 5.0     353
# 6.0      61
# 1.0      38
# 7.0      14
# 8.0       2
# 0.0       2
# 9.0       1
# Name: bedrooms, dtype: int64

# %%
df.sort_values('bedrooms')
# Out:
#                      date      price  bedrooms  bathrooms  sqft_living  \
# 3209  2014-06-24 00:00:00  1295648.0       0.0       0.00         4810
# 2365  2014-06-12 00:00:00  1095000.0       0.0       0.00         3064
# 4556  2014-06-27 00:00:00   167500.0       1.0       1.00          690
# 784   2014-05-16 00:00:00   350000.0       1.0       1.00          700
# 3633  2014-06-30 00:00:00   410000.0       1.0       1.50         1010
# ...                   ...        ...       ...        ...          ...
# 4243  2014-07-09 00:00:00   599000.0       7.0       2.50         2580
# 1455  2014-05-28 00:00:00   999000.0       7.0       4.00         3150
# 3911  2014-07-03 00:00:00   340000.0       8.0       2.75         2790
# 1500  2014-05-28 00:00:00  1970000.0       8.0       3.50         4440
# 241   2014-05-07 00:00:00   599999.0       9.0       4.50         3830
#
#       sqft_lot  floors  view  condition  sqft_above  yr_built  yr_renovated  \
# ...

# %%
df.replace(['1295648.0'],[500])
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  view  condition  sqft_above  yr_built  yr_renovated  \
# ...

# %%
df.drop_duplicates()
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  view  condition  sqft_above  yr_built  yr_renovated  \
# ...

# %%
obj=df.groupby('city')

# %%
obj.get_group('Shoreline')
# Out:
#                      date          price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  313000.000000       3.0       1.50         1340
# 33    2014-05-02 00:00:00  625000.000000       4.0       2.50         2820
# 42    2014-05-02 00:00:00  308500.000000       2.0       1.00          850
# 85    2014-05-05 00:00:00  400000.000000       2.0       1.75         2110
# 120   2014-05-05 00:00:00  379950.000000       4.0       1.75         1970
# ...                   ...            ...       ...        ...          ...
# 4363  2014-05-07 00:00:00  176225.000000       3.0       2.00         1570
# 4426  2014-05-28 00:00:00  282508.888889       3.0       1.00         1180
# 4486  2014-06-12 00:00:00  229629.500000       2.0       1.00         1100
# 4580  2014-07-07 00:00:00  282508.888889       3.0       1.00         1560
# 4587  2014-07-08 00:00:00  229629.500000       2.0       1.00          770
#
# ...

# %%
df['country'].unique()
# Out:
# array(['USA'], dtype=object)

# %%
df.dtypes
# Out:
# date             object
# price           float64
# bedrooms        float64
# bathrooms       float64
# sqft_living       int64
# sqft_lot          int64
# floors            int32
# view              int64
# condition         int64
# sqft_above        int64
# yr_built          int64
# yr_renovated      int64
# street           object
# city             object
# statezip         object
# country          object
# dtype: object

# %%
df['floors']=df['floors'].astype('int')

# %%
df.isnull().sum()
# Out:
# date            0
# price           0
# bedrooms        0
# bathrooms       0
# sqft_living     0
# sqft_lot        0
# floors          0
# view            0
# condition       0
# sqft_above      0
# yr_built        0
# yr_renovated    0
# street          0
# city            0
# statezip        0
# country         0
# dtype: int64

# %%
df.loc['df1'].iloc[1:3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 df.loc['df1'].iloc[1:3]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
p
# Out:
#                      date  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-05-02 00:00:00       3.0       1.50         1340      7912
# 1     2014-05-02 00:00:00       5.0       2.50         3650      9050
# 2     2014-05-02 00:00:00       3.0       2.00         1930     11947
# 3     2014-05-02 00:00:00       3.0       2.25         2000      8030
# 4     2014-05-02 00:00:00       4.0       2.50         1940     10500
# ...                   ...       ...        ...          ...       ...
# 4595  2014-07-09 00:00:00       3.0       1.75         1510      6360
# 4596  2014-07-09 00:00:00       3.0       2.50         1460      7573
# 4597  2014-07-09 00:00:00       3.0       2.50         3010      7014
# 4598  2014-07-10 00:00:00       4.0       2.00         2090      6630
# 4599  2014-07-10 00:00:00       3.0       2.50         1490      8102
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\tested.csv")

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0          892         0       3                  Kelly, Mr. James    male
# 1          893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2          894         0       2         Myles, Mr. Thomas Francis    male
# 3          895         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3  27.0      0      0  315154  8.6625   NaN        S

# %%
df.shape
# Out:
# (418, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  4 non-null      int64
#  1   Survived     4 non-null      int64
#  2   Pclass       4 non-null      int64
#  3   Name         4 non-null      object
#  4   Sex          4 non-null      object
#  5   Age          4 non-null      float64
#  6   SibSp        4 non-null      int64
#  7   Parch        4 non-null      int64
#  8   Ticket       4 non-null      object
#  9   Fare         4 non-null      float64
#  10  Cabin        0 non-null      object
#  11  Embarked     4 non-null      object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 512.0+ bytes

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 47           939         0       3                   Shaughnessy, Mr. Patrick
# 283         1175         1       3                 Touma, Miss. Maria Youssef
# 92           984         1       1       Davidson, Mrs. Thornton (Orian Hays)
# 337         1229         0       3                          Elias, Mr. Joseph
# 249         1141         1       3  Khalil, Mrs. Betros (Zahie Maria" Elias)"
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# 47     male   NaN      0      0      370374   7.7500   NaN        Q
# 283  female   9.0      1      1        2650  15.2458   NaN        C
# 92   female  27.0      1      2  F.C. 12750  52.0000   B71        S
# 337    male  39.0      0      2        2675   7.2292   NaN        C
# 249  female   NaN      1      0        2660  14.4542   NaN        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df[['PassengerId','Survived','Name']]
# Out:
#      PassengerId  Survived                                          Name
# 0            892         0                              Kelly, Mr. James
# 1            893         1              Wilkes, Mrs. James (Ellen Needs)
# 2            894         0                     Myles, Mr. Thomas Francis
# 3            895         0                              Wirz, Mr. Albert
# 4            896         1  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...       ...                                           ...
# 413         1305         0                            Spector, Mr. Woolf
# 414         1306         1                  Oliva y Ocana, Dona. Fermina
# 415         1307         0                  Saether, Mr. Simon Sivertsen
# 416         1308         0                           Ware, Mr. Frederick
# 417         1309         0                      Peter, Master. Michael J
#
# [418 rows x 3 columns]

# %%
df[[col for col in df.columns if col not in ['Fare','SibSp']]]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0
# 3                                Wirz, Mr. Albert    male  27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ..                                            ...     ...   ...    ...
# ...

# %%
df.rename({'Survived':'taget_feature','Sex':'Gender'},axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.set_index('Name')
# Out:
#                                               PassengerId  taget_feature  \
# Name
# Kelly, Mr. James                                      892              0
# Wilkes, Mrs. James (Ellen Needs)                      893              1
# Myles, Mr. Thomas Francis                             894              0
# Wirz, Mr. Albert                                      895              0
# Hirvonen, Mrs. Alexander (Helga E Lindqvist)          896              1
# ...                                                   ...            ...
# Spector, Mr. Woolf                                   1305              0
# Oliva y Ocana, Dona. Fermina                         1306              1
# Saether, Mr. Simon Sivertsen                         1307              0
# Ware, Mr. Frederick                                  1308              0
# Peter, Master. Michael J                             1309              0
#
#                                               Pclass  Gender   Age  SibSp  \
# Name
# ...

# %%
df.loc[:,['Name','taget_feature','PassengerId']]
# Out:
#                                              Name  taget_feature  PassengerId
# 0                                Kelly, Mr. James              0          892
# 1                Wilkes, Mrs. James (Ellen Needs)              1          893
# 2                       Myles, Mr. Thomas Francis              0          894
# 3                                Wirz, Mr. Albert              0          895
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)              1          896
# ..                                            ...            ...          ...
# 413                            Spector, Mr. Woolf              0         1305
# 414                  Oliva y Ocana, Dona. Fermina              1         1306
# 415                  Saether, Mr. Simon Sivertsen              0         1307
# 416                           Ware, Mr. Frederick              0         1308
# 417                      Peter, Master. Michael J              0         1309
#
# [418 rows x 3 columns]

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.iloc[:,:5]
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# ...

# %%
df['Pranay_rec']=500

# %%
df.loc[0,'Pranay_rec']=5000

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop('Pranay_rec',axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop(columns=['SibSp','Parch'],axis=1,inplace=True)

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 0            892              0       3
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 0                                Kelly, Mr. James    male  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# ..                                            ...     ...   ...
# ...

# %%
df.drop(0,inplace=True)

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df['pp']=df['Age']+df['Fare']

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
len(df['Name'])
# Out:
# 417

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'Q', 'C'], dtype=object)

# %%
df['Embarked'].value_counts()
# Out:
# S    270
# C    102
# Q     45
# Name: Embarked, dtype: int64

# %%
df.sort_values('Embarked')
# Out:
#      PassengerId  taget_feature  Pclass  \
# 417         1309              0       3
# 85           977              0       3
# 314         1206              1       1
# 166         1058              0       1
# 368         1260              1       1
# ..           ...            ...     ...
# 169         1061              1       3
# 167         1059              0       3
# 165         1057              1       3
# 192         1084              0       3
# 209         1101              0       3
#
#                                            Name  Gender   Age      Ticket  \
# 417                    Peter, Master. Michael J    male   NaN        2668
# 85                           Khalil, Mr. Betros    male   NaN        2660
# 314       White, Mrs. John Stuart (Ella Holmes)  female  55.0    PC 17760
# 166                          Brandeis, Mr. Emil    male  48.0    PC 17591
# 368     Gibson, Mrs. Leonard (Pauline C Boeson)  female  45.0      112378
# ...

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df.replace(['893'],['C934'])
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df['zz']=df['Name'].apply(lambda x:x.split(' ')[1])

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 409         1301              1       3
# 411         1303              1       1
# 412         1304              1       3
# 414         1306              1       1
# 415         1307              0       3
#
#                                                 Name  Gender  Age  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female   47
# 2                          Myles, Mr. Thomas Francis    male   62
# 3                                   Wirz, Mr. Albert    male   27
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female   22
# 5                         Svensson, Mr. Johan Cervin    male   14
# ..                                               ...     ...  ...
# ...

# %%
df[df['Gender']==df['Gender'].max()]
# Out:
#      PassengerId  taget_feature  Pclass                          Name Gender  \
# 2            894              0       2     Myles, Mr. Thomas Francis   male
# 3            895              0       3              Wirz, Mr. Albert   male
# 5            897              0       3    Svensson, Mr. Johan Cervin   male
# 7            899              0       2  Caldwell, Mr. Albert Francis   male
# 9            901              0       3       Davies, Mr. John Samuel   male
# ..           ...            ...     ...                           ...    ...
# 407         1299              0       1    Widener, Mr. George Dunton   male
# 413         1305              0       3            Spector, Mr. Woolf   male
# 415         1307              0       3  Saether, Mr. Simon Sivertsen   male
# 416         1308              0       3           Ware, Mr. Frederick   male
# 417         1309              0       3      Peter, Master. Michael J   male
#
# ...

# %%
df['Age'].mean()
# Out:
# 30.259818731117825

# %%
df.head(4)
# Out:
#    PassengerId  taget_feature  Pclass  \
# 1          893              1       3
# 2          894              0       2
# 3          895              0       3
# 4          896              1       3
#
#                                            Name  Gender   Age   Ticket  \
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0   363272
# 2                     Myles, Mr. Thomas Francis    male  62.0   240276
# 3                              Wirz, Mr. Albert    male  27.0   315154
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0  3101298
#
#       Fare Cabin Embarked       pp    zz
# 1   7.0000   NaN        S  54.0000  Mrs.
# 2   9.6875   NaN        Q  71.6875   Mr.
# 3   8.6625   NaN        S  35.6625   Mr.
# 4  12.2875   NaN        S  34.2875  Mrs.

# %%
df[df['Age']==df['Age'].max()][['Gender','Embarked']]
# Out:
#     Gender Embarked
# 96  female        S

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# taget_feature      0
# Pclass             0
# Name               0
# Gender             0
# Age               86
# Ticket             0
# Fare               1
# Cabin            326
# Embarked           0
# pp                87
# zz                 0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df.dropna(inplace)
# Out:
#      PassengerId  taget_feature  Pclass  \
# 12           904              1       1
# 14           906              1       1
# 24           916              1       1
# 26           918              1       1
# 28           920              0       1
# ..           ...            ...     ...
# 404         1296              0       1
# 405         1297              0       2
# 407         1299              0       1
# 411         1303              1       1
# 414         1306              1       1
#
#                                                   Name  Gender   Age  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0
# 28                             Brady, Mr. John Bertram    male  41.0
# ...

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df.dropna(thresh=0)
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
df['Cabin']=df['Cabin'].fillna('C858')

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 413         1305              0       3
# 414         1306              1       1
# 415         1307              0       3
# 416         1308              0       3
# 417         1309              0       3
#
#                                              Name  Gender   Age  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                       Myles, Mr. Thomas Francis    male  62.0
# 3                                Wirz, Mr. Albert    male  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                      Svensson, Mr. Johan Cervin    male  14.0
# ..                                            ...     ...   ...
# ...

# %%
obj=df.groupby('Embarked')

# %%
obj.get_group('Q')
# Out:
#      PassengerId  taget_feature  Pclass  \
# 2            894              0       2
# 6            898              1       3
# 16           908              0       2
# 47           939              0       3
# 55           947              0       3
# 63           955              1       3
# 66           958              1       3
# 70           962              1       3
# 79           971              1       3
# 84           976              0       2
# 86           978              1       3
# 88           980              1       3
# 102          994              0       3
# 106          998              0       3
# 107          999              0       3
# 111         1003              1       3
# 113         1005              1       3
# 121         1013              0       3
# 124         1016              0       3
# 127         1019              1       3
# 160         1052              1       3
# 183         1075              0       3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 330 entries, 1 to 415
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PassengerId    330 non-null    int64
#  1   taget_feature  330 non-null    int64
#  2   Pclass         330 non-null    int64
#  3   Name           330 non-null    object
#  4   Gender         330 non-null    object
#  5   Age            330 non-null    int64
#  6   Ticket         330 non-null    object
#  7   Fare           330 non-null    float64
#  8   Cabin          330 non-null    object
#  9   Embarked       330 non-null    object
#  10  pp             330 non-null    float64
#  11  zz             330 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 33.5+ KB

# %%
df['Age']=df['Age'].astype('int64')

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# taget_feature    0
# Pclass           0
# Name             0
# Gender           0
# Age              0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         0
# pp               0
# zz               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  taget_feature  Pclass  \
# 1            893              1       3
# 2            894              0       2
# 3            895              0       3
# 4            896              1       3
# 5            897              0       3
# ..           ...            ...     ...
# 409         1301              1       3
# 411         1303              1       1
# 412         1304              1       3
# 414         1306              1       1
# 415         1307              0       3
#
#                                                 Name  Gender   Age  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 2                          Myles, Mr. Thomas Francis    male  62.0
# 3                                   Wirz, Mr. Albert    male  27.0
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 5                         Svensson, Mr. Johan Cervin    male  14.0
# ..                                               ...     ...   ...
# ...

# %%
df.describe().T
# Out:
#                count         mean         std     min       25%         50%  \
# PassengerId    330.0  1100.863636  122.558700  893.00  993.5000  1100.50000
# taget_feature  330.0     0.384848    0.487298    0.00    0.0000     0.00000
# Pclass         330.0     2.139394    0.846211    1.00    1.0000     2.00000
# Age            330.0    30.139394   14.149182    0.00   21.0000    27.00000
# Fare           330.0    41.082551   61.294212    0.00    8.0500    16.05000
# pp             330.0    71.250732   67.400234   10.18   33.1375    48.10415
#
#                        75%        max
# PassengerId    1210.750000  1307.0000
# taget_feature     1.000000     1.0000
# Pclass            3.000000     3.0000
# Age              39.000000    76.0000
# Fare             41.106275   512.3292
# pp               80.444775   570.3292

# %%
import numpy as np

# %%
df.replace(np.nan,'Python')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex     Age  SibSp  \
# 0                                Kelly, Mr. James    male    34.5      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female    47.0      1
# 2                       Myles, Mr. Thomas Francis    male    62.0      0
# 3                                Wirz, Mr. Albert    male    27.0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female    22.0      1
# ..                                            ...     ...     ...    ...
# ...

# %%
df.replace(['male','female'],[1,0])
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name  Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    1  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)    0  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    1  62.0      0      0
# 3                                Wirz, Mr. Albert    1  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0  22.0      1      1
# ..                                            ...  ...   ...    ...    ...
# ...

# %%
df.groupby('Embarked')

# %%
obj=df.groupby('Embarked')

# %%
obj.get_group('S')
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 7            899         0       2
# ..           ...       ...     ...
# 409         1301         1       3
# 412         1304         1       3
# 413         1305         0       3
# 415         1307         0       3
# 416         1308         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# 7                    Caldwell, Mr. Albert Francis    male  26.0      1      1
# ...

# %%
obj.size()
# Out:
# Embarked
# C    102
# Q     46
# S    270
# dtype: int64

# %%
df.columns=['Age','Name']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[126], line 1
# ----> 1 df.columns=['Age','Name']
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5915, in NDFrame.__setattr__(self, name, value)
#    5913 try:
#    5914     object.__getattribute__(self, name)
# -> 5915     return object.__setattr__(self, name, value)
#    5916 except AttributeError:
#    5917     pass
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:823, in NDFrame._set_axis(self, axis, labels)
#     821 def _set_axis(self, axis: int, labels: AnyArrayLike | list) -> None:
#     822     labels = ensure_index(labels)
# --> 823     self._mgr.set_axis(axis, labels)
#     824     self._clear_item_cache()
#
# ...

# %%
new_col=pd.Series([100,200,300])

# %%
df=pd.concat([df,new_col],axis=1)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
