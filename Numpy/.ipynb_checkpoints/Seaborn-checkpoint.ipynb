# %%
import seaborn as sns
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\iris.csv")

# %%
df.shape
# Out:
# (150, 5)

# %%
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.displot(df['petal_length'],kde=False)

# %%
sns.distplot(df['petal_length'])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4736\1576753295.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'])
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.distplot(df['petal_length'])
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_4736\2232235335.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['petal_length'])

# %%
sns.jointplot(x='petal_length',y='petal_width',data=df)

# %%
sns.jointplot(x='petal_length',y='petal_width',data=df,kind='hex')

# %%
sns.pairplot(df,hue='species',diag_kind="kde",kind='scatter',palette='husl')
plt.show()

# %%
sns.stripplot(x='species',y='petal_length',data=df)
plt.show()

# %%
sns.boxplot(x='species',y='petal_length',data=df)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
plt.scatter(sepal_length,petal_length)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 plt.scatter(sepal_length,petal_length)
#
# NameError: name 'sepal_length' is not defined

# %%
import numpy as np

# %%
a=np.array([(1,2,3,4),(5,6,7,8)])

# %%
a
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])
