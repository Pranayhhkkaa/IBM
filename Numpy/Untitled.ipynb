# %%
emp_details={'ID':[1,2,3],"Name":['Pranay']}

# %%
import pandas as pd

# %%
import pandas as pd

# Example DataFrames
df1 = pd.DataFrame({'A': [1, 2], 'B': [3, 4]})
df2 = pd.DataFrame({'A': [5, 6], 'B': [7, 8]})

# Append with ignore_index=True
result = df1.append(df2, ignore_index=True)
print(result)
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  5  7
# 3  6  8
# C:\Users\User\AppData\Local\Temp\ipykernel_14984\842478595.py:8: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   result = df1.append(df2, ignore_index=True)

# %%
import pandas as pd

# Example DataFrame
data = {'Name': ['Alice', 'Bob', 'Charlie'],
        'Age': [25, 30, 35],
        'City': ['New York', 'San Francisco', 'Los Angeles']}

df = pd.DataFrame(data)

# Display the original DataFrame
print("Original DataFrame:")
print(df)

# Applying ignore_index=True when appending a new row
new_row = pd.Series(['David', 40, 'Chicago'], index=df.columns)
df = df.append(new_row, ignore_index=True)

# Display the modified DataFrame
print("\nDataFrame after appending a new row with ignore_index=True:")
print(df)
# Out:
# Original DataFrame:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
#
# DataFrame after appending a new row with ignore_index=True:
#       Name  Age           City
# 0    Alice   25       New York
# 1      Bob   30  San Francisco
# 2  Charlie   35    Los Angeles
# 3    David   40        Chicago
# C:\Users\User\AppData\Local\Temp\ipykernel_14984\2918423032.py:16: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_row, ignore_index=True)

# %%
emp_details=[('1','Pranay','Pune'),
            ('2','Rashmi','mumbai'),
            ('3','Pratik','nashik')]

# %%
df=pd.DataFrame(emp_details,columns=['ID','Name','Location'])

# %%
df
# Out:
#   ID    Name Location
# 0  1  Pranay     Pune
# 1  2  Rashmi   mumbai
# 2  3  Pratik   nashik

# %%
df[['ID','Location']]
# Out:
#   ID Location
# 0  1     Pune
# 1  2   mumbai
# 2  3   nashik

# %%
std_info=[('1','Ram','Amravati'),
            ('2','Prajwal','mumbai'),
            ('3','Akshay','nashik')]

# %%
df1=pd.DataFrame(std_info,columns=['ID','std_Name','std_Location'])

# %%
df1
# Out:
#   ID std_Name std_Location
# 0  1      Ram     Amravati
# 1  2  Prajwal       mumbai
# 2  3   Akshay       nashik

# %%
df
# Out:
#   ID    Name Location
# 0  1  Pranay     Pune
# 1  2  Rashmi   mumbai
# 2  3  Pratik   nashik

# %%
pp=pd.merge(df,df1,on= 'ID',how='inner')
pp.ignore_index=True

# %%
ignore_index=True

# %%
pp
# Out:
#   ID    Name Location std_Name std_Location
# 0  1  Pranay     Pune      Ram     Amravati
# 1  2  Rashmi   mumbai  Prajwal       mumbai
# 2  3  Pratik   nashik   Akshay       nashik

# %%
df=pd.read_csv(r"C:\Users\User\Downloads\Bengaluru_House_Data.csv")

# %%
df.head()
# Out:
#                area_type   availability                  location       size  \
# 0   Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1             Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 3   Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 5   Super built-up  Area  Ready To Move                Whitefield      2 BHK
# 11            Plot  Area  Ready To Move                Whitefield  4 Bedroom
#
#     society total_sqft  bath  balcony   price
# 0   Coomee        1056   2.0      1.0   39.07
# 1   Theanmp       2600   5.0      3.0  120.00
# 3   Soiewre       1521   3.0      1.0   95.00
# 5   DuenaTa       1170   2.0      1.0   38.00
# 11  Prrry M       2785   5.0      3.0  295.00

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.describe(include='all')
# Out:
#                    area_type   availability    location   size  society  \
# count                   7496           7496        7496   7496     7496
# unique                     4             74         634     15     2592
# top     Super built-up  Area  Ready To Move  Whitefield  2 BHK  GrrvaGr
# freq                    6017           5709         397   3411       80
# mean                     NaN            NaN         NaN    NaN      NaN
# std                      NaN            NaN         NaN    NaN      NaN
# min                      NaN            NaN         NaN    NaN      NaN
# 25%                      NaN            NaN         NaN    NaN      NaN
# 50%                      NaN            NaN         NaN    NaN      NaN
# 75%                      NaN            NaN         NaN    NaN      NaN
# max                      NaN            NaN         NaN    NaN      NaN
#
#        total_sqft         bath      balcony        price
# ...

# %%
df[df['balcony']>2.0]
# Out:
#                   area_type   availability               location       size  \
# 1                Plot  Area  Ready To Move       Chikka Tirupathi  4 Bedroom
# 11               Plot  Area  Ready To Move             Whitefield  4 Bedroom
# 17     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 33     Super built-up  Area  Ready To Move  Raja Rajeshwari Nagar      3 BHK
# 54     Super built-up  Area  Ready To Move              Yelahanka      3 BHK
# ...                     ...            ...                    ...        ...
# 13242  Super built-up  Area  Ready To Move     8th Phase JP Nagar      3 BHK
# 13243  Super built-up  Area  Ready To Move           Doddathoguru      3 BHK
# 13253  Super built-up  Area  Ready To Move        Old Madras Road      2 BHK
# 13294  Super built-up  Area  Ready To Move          Sultan Palaya      4 BHK
# 13314  Super built-up  Area  Ready To Move      Green Glen Layout      3 BHK
#
# ...

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath              int32
# balcony         float64
# price           float64
# dtype: object

# %%
df['bath']=df['bath'].astype('int32')

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056     2      1.0   39.07
# ...

# %%
ignore_index=True

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13313  Super built-up  Area  Ready To Move               Uttarahalli
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056     2      1.0   39.07
# ...

# %%
import numpy as np

# %%
import sys

# %%
sys.getsizeof(ele)
